# %%
# %%writefile summarize.py
import argparse
import json

def analyze_clause(text):
    """
    This is your TOS Translator logic.
    Replace the summary, risk logic, and flags with your model later.
    For now, this produces clean JSON output for testing.
    """

    # --- Simple rule-based example (replace with your model later) ---
    summary = (
        "Google uses AI and machine learning to improve services and may "
        "add, remove, or modify features at any time. Software tied to these "
        "services may update automatically unless the user changes update settings."
    )

    risk_level = "medium"

    flags = [
        "automatic_updates",
        "feature_removal",
        "service_discontinuation",
        "ai_processing",
        "reduced_user_control"
    ]

    result = {
        "clause_id": "G-Updates-1",
        "section": "Service Improvements and Updates",
        "original_text": text,
        "summary": summary,
        "risk_level": risk_level,
        "flags": flags,
        "category": "service_changes",
        "notes": "Automatic updates may alter functionality without explicit user approval. Feature removal may impact service reliability."
    }

    return result


if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Summarize a TOS clause.")
    parser.add_argument("--text", type=str, required=True, help="Clause to summarize")
    args = parser.parse_args()

    output = analyze_clause(args.text)
    print(json.dumps(output, indent=4))
# Out:
# Writing summarize.py

# %%
# !python summarize.py --text "We’re constantly developing new technologies and features to improve our services. For example, we use artificial intelligence and machine learning to provide you with simultaneous translations, and to better detect and block spam and malware. As part of this continual improvement, we sometimes add or remove features and functionalities, increase or decrease limits to our services, and start offering new services or stop offering old ones. When a service requires or includes downloadable or preloaded software, that software sometimes updates automatically on your device once a new version or feature is available. Some services let you adjust your automatic update settings."
# Out:
# {
#     "clause_id": "G-Updates-1",
#     "section": "Service Improvements and Updates",
#     "original_text": "We\u2019re constantly developing new technologies and features to improve our services. For example, we use artificial intelligence and machine learning to provide you with simultaneous translations, and to better detect and block spam and malware. As part of this continual improvement, we sometimes add or remove features and functionalities, increase or decrease limits to our services, and start offering new services or stop offering old ones. When a service requires or includes downloadable or preloaded software, that software sometimes updates automatically on your device once a new version or feature is available. Some services let you adjust your automatic update settings.",
# ...

# %%
# %%writefile summarize.py
import argparse
import json

def analyze_clause(text):
    """
    TOS Translator logic placeholder.
    Replace with your model later.
    """

    # --- Rule-based example for testing ---
    summary = (
        "Google will notify users in advance if a major change negatively affects service use "
        "or if a service is discontinued, except in urgent cases. Users can export their data "
        "using Google Takeout when allowed by law."
    )

    risk_level = "medium"

    flags = [
        "service_discontinuation",
        "material_changes",
        "limited_notice_exceptions",
        "data_export_rights"
    ]

    result = {
        "clause_id": "G-Notice-1",
        "section": "Service Changes and User Notice",
        "original_text": text,
        "summary": summary,
        "risk_level": risk_level,
        "flags": flags,
        "category": "user_rights_and_notifications",
        "notes": "Notice may not be provided in urgent cases. Data export is subject to legal limits."
    }

    return result


if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Summarize a TOS clause.")
    parser.add_argument("--text", type=str, required=True, help="Clause to summarize")
    args = parser.parse_args()

    output = analyze_clause(args.text)
    print(json.dumps(output, indent=4))
# Out:
# Overwriting summarize.py

# %%
# !python summarize.py --text "If we make material changes that negatively impact your use of our services or if we stop offering a service, we’ll provide you with reasonable advance notice, except in urgent situations such as preventing abuse, responding to legal requirements, or addressing security and operability issues. We’ll also provide you with an opportunity to export your content from your Google Account using Google Takeout, subject to applicable law and policies."
# Out:
# {
#     "clause_id": "G-Notice-1",
#     "section": "Service Changes and User Notice",
#     "original_text": "If we make material changes that negatively impact your use of our services or if we stop offering a service, we\u2019ll provide you with reasonable advance notice, except in urgent situations such as preventing abuse, responding to legal requirements, or addressing security and operability issues. We\u2019ll also provide you with an opportunity to export your content from your Google Account using Google Takeout, subject to applicable law and policies.",
#     "summary": "Google will notify users in advance if a major change negatively affects service use or if a service is discontinued, except in urgent cases. Users can export their data using Google Takeout when allowed by law.",
#     "risk_level": "medium",
#     "flags": [
#         "service_discontinuation",
#         "material_changes",
#         "limited_notice_exceptions",
#         "data_export_rights"
#     ],
# ...

# %%
# %%writefile summarize.py
import argparse
import json

def analyze_clause(text):
    # TOS Translator logic placeholder.
    # Replace with your model later.

    summary = (
        "Google offers many types of services—apps, sites, platforms, "
        "integrated tools, and physical devices. All of these fall under "
        "the same Terms of Service, and many include interactive or "
        "streamable content."
    )

    risk_level = "low"

    flags = [
        "broad_service_scope",
        "multi_platform_integration",
        "device_integration",
        "content_interaction"
    ]

    result = {
        "clause_id": "G-Scope-1",
        "section": "Scope of Services",
        "original_text": text,
        "summary": summary,
        "risk_level": risk_level,
        "flags": flags,
        "category": "service_scope",
        "notes": "This clause defines the range of Google services covered by the Terms."
    }

    return result

if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Summarize a TOS clause.")
    parser.add_argument("--text", type=str, required=True, help="Clause to summarize")
    args = parser.parse_args()
    output = analyze_clause(args.text)
    print(json.dumps(output, indent=4))
# Out:
# Overwriting summarize.py

# %%
# !python summarize.py --text "We provide a broad range of services that are subject to these terms, including: apps and sites (like Search and Maps), platforms (like Google Shopping), integrated services (like Maps embedded in other companies’ apps or sites), devices (like Google Nest and Pixel). Many of these services also include content that you can stream or interact with."
# Out:
# {
#     "clause_id": "G-Scope-1",
#     "section": "Scope of Services",
#     "original_text": "We provide a broad range of services that are subject to these terms, including: apps and sites (like Search and Maps), platforms (like Google Shopping), integrated services (like Maps embedded in other companies\u2019 apps or sites), devices (like Google Nest and Pixel). Many of these services also include content that you can stream or interact with.",
#     "summary": "Google offers many types of services\u2014apps, sites, platforms, integrated tools, and physical devices. All of these fall under the same Terms of Service, and many include interactive or streamable content.",
#     "risk_level": "low",
#     "flags": [
#         "broad_service_scope",
#         "multi_platform_integration",
#         "device_integration",
#         "content_interaction"
#     ],
#     "category": "service_scope",
#     "notes": "This clause defines the range of Google services covered by the Terms."
# ...

# %%
# %%writefile summarize.py
import argparse
import json

def analyze_clause(text):
    # TOS Translator logic placeholder.
    # Replace with your model later.

    summary = (
        "Google requires users to follow the Privacy Policy when using its services. "
        "Google also provides help resources such as the Copyright Help Center, "
        "Safety Center, Transparency Center, and technology explanations to clarify "
        "expectations. Services may also include warnings or instructions, such as "
        "dialog boxes that highlight important information."
    )

    risk_level = "low"

    flags = [
        "privacy_policy_binding",
        "user_guidance_resources",
        "service_warnings",
        "instructional_dialogs"
    ]

    result = {
        "clause_id": "G-Privacy-1",
        "section": "Privacy and User Guidance",
        "original_text": text,
        "summary": summary,
        "risk_level": risk_level,
        "flags": flags,
        "category": "privacy_and_guidance",
        "notes": "This clause binds users to the Privacy Policy and explains Google’s guidance resources."
    }

    return result

if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Summarize a TOS clause.")
    parser.add_argument("--text", type=str, required=True, help="Clause to summarize")
    args = parser.parse_args()
    output = analyze_clause(args.text)
    print(json.dumps(output, indent=4))
# Out:
# Overwriting summarize.py

# %%
# !python summarize.py --text "You also agree that our Privacy Policy applies to your use of our services. We also provide resources like the Copyright Help Center, Safety Center, Transparency Center, and descriptions of our technologies from our policies site to answer common questions and to set expectations about using our services. Finally, we may provide specific instructions and warnings within our services – such as dialog boxes that alert you to important information."
# Out:
# {
#     "clause_id": "G-Privacy-1",
#     "section": "Privacy and User Guidance",
#     "original_text": "You also agree that our Privacy Policy applies to your use of our services. We also provide resources like the Copyright Help Center, Safety Center, Transparency Center, and descriptions of our technologies from our policies site to answer common questions and to set expectations about using our services. Finally, we may provide specific instructions and warnings within our services \u2013 such as dialog boxes that alert you to important information.",
#     "summary": "Google requires users to follow the Privacy Policy when using its services. Google also provides help resources such as the Copyright Help Center, Safety Center, Transparency Center, and technology explanations to clarify expectations. Services may also include warnings or instructions, such as dialog boxes that highlight important information.",
#     "risk_level": "low",
#     "flags": [
# ...

# %%
# %%writefile summarize.py
import argparse
import json

def analyze_clause(text):
    # TOS Translator logic placeholder.
    # Replace with your model later.

    summary = (
        "Users must not abuse or interfere with Google services. Prohibited actions "
        "include malware, hacking, bypassing protections, spamming, fraudulent use, "
        "fake accounts, misleading others about AI-generated content, violating legal "
        "rights, reverse engineering, unauthorized automated scraping, using Google "
        "AI outputs to build competing models, and hiding identity to break rules."
    )

    risk_level = "high"

    flags = [
        "malware_prohibition",
        "security_bypass",
        "fraud_and_deception",
        "fake_accounts",
        "ai_misrepresentation",
        "ip_privacy_violations",
        "reverse_engineering",
        "unauthorized_scraping",
        "ai_model_training_restriction",
        "identity_misrepresentation"
    ]

    result = {
        "clause_id": "G-Abuse-1",
        "section": "Prohibited Conduct and Abuse Prevention",
        "original_text": text,
        "summary": summary,
        "risk_level": risk_level,
        "flags": flags,
        "category": "prohibited_actions",
        "notes": "This clause lists actions that violate Google's rules and threaten service integrity."
    }

    return result

if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Summarize a TOS clause.")
    parser.add_argument("--text", type=str, required=True, help="Clause to summarize")
    args = parser.parse_args()
    output = analyze_clause(args.text)
    print(json.dumps(output, indent=4))
# Out:
# Overwriting summarize.py

# %%
# !python summarize.py --text "Most people who access or use our services understand the general rules that keep the internet safe and open. Unfortunately, a small number of people don’t respect those rules, so we’re describing them here to protect our services and users from abuse. In that spirit: You must not abuse, harm, interfere with, or disrupt our services or systems — for example, by: introducing malware; spamming, hacking, or bypassing our systems or protective measures; jailbreaking, adversarial prompting, or prompt injection, except as part of our safety and bug testing programs; accessing or using our services or content in fraudulent or deceptive ways, such as phishing, creating fake accounts or content, misleading others into thinking that generative AI content was created by a human, providing services that appear to originate from you (or someone else) when they actually originate from us, providing services that appear to originate from us when they do not; using our services to violate legal rights; reverse engineering our services or models; using automated means to access content in violation of robots.txt; using AI-generated content from our services to develop machine learning models; hiding or misrepresenting who you are to violate these terms."
# Out:
# {
#     "clause_id": "G-Abuse-1",
#     "section": "Prohibited Conduct and Abuse Prevention",
# ...

# %%
# %%writefile summarize.py
import argparse
import json

def analyze_clause(text):
    summary = (
        "This clause explains that the terms define the legal relationship between "
        "the user and Google. 'Google' refers to Google LLC and its affiliates. "
        "Google allows users to access its services as long as they agree to follow "
        "the Terms of Service, which reflect how Google operates and earns revenue."
    )

    risk_level = "low"

    flags = [
        "relationship_definition",
        "service_access_condition",
        "business_model_reference"
    ]

    result = {
        "clause_id": "G-Relationship-1",
        "section": "Relationship Between User and Google",
        "original_text": text,
        "summary": summary,
        "risk_level": risk_level,
        "flags": flags,
        "category": "legal_relationship",
        "notes": "Defines who 'Google' refers to and the conditions for accessing services."
    }

    return result

if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Summarize a TOS clause.")
    parser.add_argument("--text", type=str, required=True, help="Clause to summarize")
    args = parser.parse_args()
    output = analyze_clause(args.text)
    print(json.dumps(output, indent=4))
# Out:
# Overwriting summarize.py

# %%
# !python summarize.py --text "These terms help define the relationship between you and Google. When we speak of 'Google,' 'we,' 'us,' and 'our,' we mean Google LLC and its affiliates. Broadly speaking, we give you permission to access and use our services if you agree to follow these terms, which reflect how Google’s business works and how we earn money."
# Out:
# {
#     "clause_id": "G-Relationship-1",
#     "section": "Relationship Between User and Google",
#     "original_text": "These terms help define the relationship between you and Google. When we speak of 'Google,' 'we,' 'us,' and 'our,' we mean Google LLC and its affiliates. Broadly speaking, we give you permission to access and use our services if you agree to follow these terms, which reflect how Google\u2019s business works and how we earn money.",
#     "summary": "This clause explains that the terms define the legal relationship between the user and Google. 'Google' refers to Google LLC and its affiliates. Google allows users to access its services as long as they agree to follow the Terms of Service, which reflect how Google operates and earns revenue.",
#     "risk_level": "low",
#     "flags": [
#         "relationship_definition",
#         "service_access_condition",
#         "business_model_reference"
#     ],
#     "category": "legal_relationship",
# ...

# %%
# %%writefile summarize.py
import argparse
import json

def analyze_clause(text):
    summary = (
        "Users who are under the required age to manage their own Google Account "
        "must have permission from a parent or legal guardian. The parent or guardian "
        "must review the terms with the minor before the account is used."
    )

    risk_level = "medium"

    flags = [
        "age_requirement",
        "parental_consent",
        "minor_protection"
    ]

    result = {
        "clause_id": "G-Age-1",
        "section": "Age Requirements and Parental Permission",
        "original_text": text,
        "summary": summary,
        "risk_level": risk_level,
        "flags": flags,
        "category": "eligibility_requirements",
        "notes": "Establishes age limits and requires parental consent for minors."
    }

    return result

if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Summarize a TOS clause.")
    parser.add_argument("--text", type=str, required=True, help="Clause to summarize")
    args = parser.parse_args()
    output = analyze_clause(args.text)
    print(json.dumps(output, indent=4))
# Out:
# Overwriting summarize.py

# %%
# !python summarize.py --text "If you’re under the age required to manage your own Google Account, you must have your parent or legal guardian’s permission to use a Google Account. Please have your parent or legal guardian read these terms with you."
# Out:
# {
#     "clause_id": "G-Age-1",
#     "section": "Age Requirements and Parental Permission",
#     "original_text": "If you\u2019re under the age required to manage your own Google Account, you must have your parent or legal guardian\u2019s permission to use a Google Account. Please have your parent or legal guardian read these terms with you.",
#     "summary": "Users who are under the required age to manage their own Google Account must have permission from a parent or legal guardian. The parent or guardian must review the terms with the minor before the account is used.",
#     "risk_level": "medium",
#     "flags": [
#         "age_requirement",
#         "parental_consent",
#         "minor_protection"
#     ],
#     "category": "eligibility_requirements",
#     "notes": "Establishes age limits and requires parental consent for minors."
# }
